# %%
import subprocess

# %%
subprocess.run(["lmp", "-in", "inp.lammps"])
# Out:
# LAMMPS (21 Nov 2023)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:98)
#   using 1 OpenMP thread(s) per MPI task
# ERROR: Unrecognized pair style 'm3gnet' (src/force.cpp:275)
# Last command: pair_style    m3gnet ./potentials/M3GNET
# [jupyter-jan-2djanssen-2dlammps-2dmatgl-2d80qnkagn:01640] mca_base_component_repository_open: unable to open mca_btl_openib: librdmacm.so.1: cannot open shared object file: No such file or directory (ignored)
# CompletedProcess(args=['lmp', '-in', 'inp.lammps'], returncode=1)
